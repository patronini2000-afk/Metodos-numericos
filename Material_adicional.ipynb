# %% [markdown]
# <a href="https://colab.research.google.com/github/patronini2000-afk/Metodos-numericos/blob/main/Material_adicional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MATERIAL ADICIONAL
#
# Este material no constituye parte del curso, se ha guardado en este repositorio para poder consultarlo en un futuro con mayor facilidad
#
# Ejercicios 1.1
#
# 1) Demuestre que las siguientes ecuaciones tienen al menos una solución en los intervalos dados.
#
# a) $\quad xcos(x) -2x^2 + 3x - 1, \qquad [0.2,0.3] \qquad y \qquad [1.2,1.3]$
#
# SOLUCION: Consisdere la ecuación $\qquad f(x)=xcos(x) -2x^2 + 3x - 1$
#
# Determinemos los valores para $f(0.2)$ y $f(0.3)$

# %%
import numpy as np
def f(x):
  return x*np.cos(x) - 2*(x**2) + 3*(x) - 1
print(f"f(0.2)={f(0.2)}")
print(f"f(0.3)={f(0.3)}")
# Out:
# f(0.2)=-0.28398668443175157
# f(0.3)=0.0066009467376817454

# %% [markdown]
# Puesto que $f \in C[0.2,0.3]$ y $f(0.2)< 0 < f(0.3)$, por el teroema del valor intermedio tenemos que existe $c \in \mathbb{R}$ tal que $f(c)=0$, es decir, la ecuación tiene al menos una solución.
#
# Ahora determinemos los valores para $f(1.2)$ y $f(1.3)$

# %%
import numpy as np
def f(x):
  return x*np.cos(x) - 2*(x**2) + 3*(x) - 1
print(f"f(1.2)={f(1.2)}")
print(f"f(1.3)={f(1.3)}")
# Out:
# f(1.2)=0.154829305372008
# f(1.3)=-0.13225152278803654

# %% [markdown]
# Puesto que $f \in C[1.2,1.3]$ y $f(1.3)< 0 < f(1.2)$, por el teroema del valor intermedio tenemos que existe $c \in \mathbb{R}$ tal que $f(c)=0$, es decir, la ecuación tiene al menos una solución.
#
# b) $(x-2)^2 -ln x = 0, \qquad [1,2] \qquad [\mathrm{e} , 4]$
#
# Considere la función igualada a $f(x)$ en lugar de $0$ y exhibamos la función evaluada en los extremos de los intervalos

# %%
import numpy as np
def f(x):
  return np.pow(x-2,2) - np.log(x)
print(f"f(1)={f(1)}")
print(f"f(2)={f(2)}")
print(f"f(e)={f(np.exp(1))}")
print(f"f(4)={f(4)}")
# Out:
# f(1)=1.0
# f(2)=-0.6931471805599453
# f(e)=-0.48407121490553096
# f(4)=2.613705638880109

# %% [markdown]
# Por el teorema anterior existe al menos una solución en cada uno de los intervalos
#
# c) $2x \cos{(2x)} - (x-2)^2 = 0 \qquad [2,3] \qquad y \qquad [3,4]$
#
# Del mismo modo que el inciso a) y b), igualemos a $f(x)$ y evaluemos la función

# %%
import numpy as np
def f(x):
  return 2*x*np.cos(2*x) - np.pow(x-2,2)
print(f"f(2)={f(2)}")
print(f"f(3)={f(3)}")
print(f"f(4)={f(4)}")
# Out:
# f(2)=-2.6145744834544478
# f(3)=4.761021719902196
# f(4)=-5.164000270468908

# %% [markdown]
# Por el teorema anterior existe al menos una solución en cada uno de los intervalos
#
# d) $x-(\ln{x})^x=0, \qquad [4,5]$

# %%
import numpy as np
def f(x):
  return x - np.pow(np.log(x),x)
print(f"f(4)={f(4)}")
print(f"f(5)={f(5)}")
# Out:
# f(4)=0.3066384226706651
# f(5)=-5.798691578322238

# %% [markdown]
# Análogamente el inciso d) tiene al menos una solución por el Teorema del valor intermedio
#
# 3. Demuestre que $f'(x)$ es $0$ al menos una vez en los intervalos dados
#
# a) $f(x)=1-\mathrm{e}^x + (e-1)\sin (\frac{\pi}{2} x), \qquad [0,1]$
#
# Note que $f(x)$ es continua pues la exponencial y la función seno son continuas y $f(x)$ es derivable.
#
# Evaluemos la función en $0$ y $1$

# %%
import numpy as np
def f(x):
  return 1 - np.pow(np.exp(1),x) + (np.exp(1) - 1)*np.sin((np.pi*x)/2)
print(f"f(0)={f(0)}")
print(f"f(1)={f(1)}")
# Out:
# f(0)=0.0
# f(1)=0.0

# %% [markdown]
# $\therefore$ Por el teroema de role $\exists c \in \mathbb{R} \mid f'(c)=0$
#
# b) $f(x)= (x-1)\tan{x} + x \sin{(\pi x)}, \qquad [0,1]$
#
# Note que al evualuar la función en ambos extremos se tiene que...

# %%
import sympy as sp
def f(x):
  return (x-1)*sp.tan(x) + x*sp.sin(sp.pi*x)
print(f"f(0)={f(0)}")
print(f"f(1)={f(1)}")
# Out:
# f(0)=0
# f(1)=0

# %% [markdown]
# $\therefore$ Por el teroema de role $\exists c \in \mathbb{R} \mid f'(c)=0$
